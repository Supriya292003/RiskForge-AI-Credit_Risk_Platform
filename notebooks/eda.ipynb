# %% [markdown]
# # Exploratory Data Analysis - Credit Risk Intelligence
# This notebook performs data quality assessment, feature distribution checks, correlation analysis, and income/age risk profiling for loan applicants.

# %%
import os
import sys
from pathlib import Path

# Ensure project root is in system path
project_root = Path(os.getcwd()).parent
sys.path.append(str(project_root))

# Import and run exploratory analysis function
from notebooks.eda import run_exploratory_analysis
run_exploratory_analysis()
